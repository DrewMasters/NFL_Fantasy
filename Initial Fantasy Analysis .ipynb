# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
import os
print(os.getcwd())
print(os.path.isfile('./NFL_Data/2019/2019_NFL_Passing.csv'))
# Out:
# /home/drewmasters/repos/NFL_Fantasy
# True

# %%
dfPassing = pd.read_csv('./NFL_Data/2019/2019_NFL_Passing.csv', sep=r'\s*,\s*', header=0, encoding='ascii', engine='python')

# %%
dfRushing = pd.read_csv('./NFL_Data/2019/2019_NFL_Rushing.csv', sep=r'\s*,\s*', header=0, encoding='ascii', engine='python')

# %%
dfReceiving = pd.read_csv('./NFL_Data/2019/2019_NFL_Receiving.csv', sep=r'\s*,\s*', header=0, encoding='ascii', engine='python')

# %%
dfKicking = pd.read_csv('./NFL_Data/2019/2019_NFL_Kicking.csv', sep=r'\s*,\s*', header=0, encoding='ascii', engine='python')

# %%
player_columns = ['Player', 'Tm', 'Age', 'Pos', 'G', 'GS']

# %%
print(dfPassing.columns.tolist())
# Out:
# ['Rk', 'Player', 'Tm', 'Age', 'Pos', 'G', 'GS', 'QBrec', 'Cmp', 'Att', 'Cmp%', 'Yds', 'TD', 'TD%', 'Int', 'Int%', '1D', 'Lng', 'Y/A', 'AY/A', 'Y/C', 'Y/G', 'Rate', 'QBR', 'Sk', 'Yds.1', 'NY/A', 'ANY/A', 'Sk%', '4QC', 'GWD']

# %%
del dfPassing['GWD']
del dfPassing['4QC']
del dfPassing['Yds.1']
print(dfPassing.columns.tolist())
passing_columns = ['QBrec', 'Cmp', 'Att', 'Cmp%', 'Yds', 'TD', 'TD%', 'Int', 'Int%', '1D', 'Lng', 'Y/A', 'AY/A', 'Y/C', 'Y/G', 'Rate', 'QBR', 'Sk', 'NY/A', 'ANY/A', 'Sk%']
# Out:
# ['Rk', 'Player', 'Tm', 'Age', 'Pos', 'G', 'GS', 'QBrec', 'Cmp', 'Att', 'Cmp%', 'Yds', 'TD', 'TD%', 'Int', 'Int%', '1D', 'Lng', 'Y/A', 'AY/A', 'Y/C', 'Y/G', 'Rate', 'QBR', 'Sk', 'NY/A', 'ANY/A', 'Sk%']

# %%
print(dfRushing.columns.tolist())
rushing_columns = ['Att', 'Yds', 'TD', '1D', 'Lng', 'Y/A', 'Y/G', 'Fmb']
# Out:
# ['Rk', 'Player', 'Tm', 'Age', 'Pos', 'G', 'GS', 'Att', 'Yds', 'TD', '1D', 'Lng', 'Y/A', 'Y/G', 'Fmb']

# %%
print(dfReceiving.columns.tolist())
receiving_columns = ['Tgt', 'Rec', 'Ctch%', 'Yds', 'Y/R', 'TD', '1D', 'Lng', 'Y/Tgt', 'R/G', 'Y/G', 'Fmb']
# Out:
# ['Rk', 'Player', 'Tm', 'Age', 'Pos', 'G', 'GS', 'Tgt', 'Rec', 'Ctch%', 'Yds', 'Y/R', 'TD', '1D', 'Lng', 'Y/Tgt', 'R/G', 'Y/G', 'Fmb']

# %%
print(dfKicking.columns.tolist())
kicking_columns = ['FGA 0-19', 'FGM 0-19', 'FGA 20-29', 'FGM 20-29', 'FGA 30-39', 'FGM 30-39', 'FGA 40-49', 'FGM 40-49', 'FGA 50+', 'FGM 50+', 'FGA Scoring', 'FGM Scoring', 'Lng', 'FG%', 'XPA', 'XPM', 'XP%']
# Out:
# ['Rk', 'Player', 'Tm', 'Age', 'Pos', 'Games', 'GS', 'FGA 0-19', 'FGM 0-19', 'FGA 20-29', 'FGM 20-29', 'FGA 30-39', 'FGM 30-39', 'FGA 40-49', 'FGM 40-49', 'FGA 50+', 'FGM 50+', 'FGA Scoring', 'FGM Scoring', 'Lng', 'FG%', 'XPA', 'XPM', 'XP%']

# %%
pointsPerRec = 1
pointsPerPassingTD = 4
pointsPerRushingTD = 4
pointsPerReceivingTD = 4
pointsPerRushingYD = 0.1
pointsPerReceivingYd = 0.1
pointsPerPassingYd = 0.04
pointsPerFumble = -2
pointsPerINT = -2

# %%
print(dfRushing.columns.tolist())
# Out:
# ['Rk', 'Player', 'Tm', 'Age', 'Pos', 'G', 'GS', 'Att', 'Yds', 'TD', '1D', 'Lng', 'Y/A', 'Y/G', 'Fmb']

# %%
dfRushing['RushingFPs'] = dfRushing['Yds'] * pointsPerRushingYD + dfRushing['TD'] * pointsPerRushingTD + dfRushing['Fmb'] * pointsPerFumble

# %%
print(dfReceiving.columns.tolist())
# Out:
# ['Rk', 'Player', 'Tm', 'Age', 'Pos', 'G', 'GS', 'Tgt', 'Rec', 'Ctch%', 'Yds', 'Y/R', 'TD', '1D', 'Lng', 'Y/Tgt', 'R/G', 'Y/G', 'Fmb']

# %%
dfReceiving['ReceivingFPs'] = dfReceiving['Yds'] * pointsPerReceivingYd + dfReceiving['Rec'] * pointsPerRec + dfReceiving['TD'] * pointsPerReceivingTD + dfReceiving['Fmb'] * pointsPerFumble

# %%
print(dfPassing.columns.tolist())
# Out:
# ['Rk', 'Player', 'Tm', 'Age', 'Pos', 'G', 'GS', 'QBrec', 'Cmp', 'Att', 'Cmp%', 'Yds', 'TD', 'TD%', 'Int', 'Int%', '1D', 'Lng', 'Y/A', 'AY/A', 'Y/C', 'Y/G', 'Rate', 'QBR', 'Sk', 'NY/A', 'ANY/A', 'Sk%']

# %%
dfPassing['PassingFPs'] = dfPassing['Yds'] * pointsPerPassingYd + dfPassing['TD'] * pointsPerPassingTD + dfPassing['Int'] * pointsPerINT

# %%
qb_passing_df = dfPassing[dfPassing['Pos'] == 'QB']
rb_passing_df = dfPassing[dfPassing['Pos'] == 'RB']
k_passing_df = dfPassing[dfPassing['Pos'] == 'K']
wr_passing_df = dfPassing[dfPassing['Pos'] == 'WR']

# %%
qb_rushing_df = dfRushing[dfRushing['Pos'] == 'QB']
rb_rushing_df = dfRushing[dfRushing['Pos'] == 'RB']
k_rushing_df = dfRushing[dfRushing['Pos'] == 'K']
wr_rushing_df = dfRushing[dfRushing['Pos'] == 'WR']

# %%
qb_receiving_df = dfReceiving[dfReceiving['Pos'] == 'QB']
rb_receiving_df = dfReceiving[dfReceiving['Pos'] == 'RB']
k_receiving_df = dfReceiving[dfReceiving['Pos'] == 'K']
wr_receiving_df = dfReceiving[dfReceiving['Pos'] == 'WR']

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots()
fig.set_size_inches(15,10)

plot = sns.regplot(
        x = rb_rushing_df['Att'],
        y = rb_rushing_df['RushingFPs'],
        scatter=True,)

# %%
plot = sns.regplot(
        x = wr_rushing_df['Att'],
        y = wr_rushing_df['RushingFPs'],
        scatter=True,)

# %%
plot = sns.regplot(
        x = qb_rushing_df['Att'],
        y = qb_rushing_df['RushingFPs'],
        scatter=True,)

# %%
plot = sns.regplot(
        x = wr_receiving_df['Tgt'],
        y = wr_receiving_df['ReceivingFPs'],
        scatter=True,)

# %%
plot = sns.regplot(
        x = rb_receiving_df['Tgt'],
        y = rb_receiving_df['ReceivingFPs'],
        scatter=True,)

# %%
plot = sns.regplot(
        x = qb_receiving_df['Tgt'],
        y = qb_receiving_df['ReceivingFPs'],
        scatter=True,)

# %%
plot = sns.regplot(
        x = qb_passing_df['Att'],
        y = qb_passing_df['PassingFPs'],
        scatter=True,)

# %%
plot = sns.regplot(
        x = qb_passing_df['Cmp'],
        y = qb_passing_df['PassingFPs'],
        scatter=True,)

# %%
plot = sns.regplot(
        x = qb_passing_df['Cmp'],
        y = qb_passing_df['TD'],
        scatter=True,)

# %%
plot = sns.regplot(
        x = qb_passing_df['Att'],
        y = qb_passing_df['TD'],
        scatter=True,)

# %%
plot = sns.regplot(
        x = qb_passing_df['Att'],
        y = qb_passing_df['Int'],
        scatter=True,)

# %%
plot = sns.regplot(
        x = qb_passing_df['Cmp'],
        y = qb_passing_df['Int'],
        scatter=True,)

# %%
import statsmodels.api as sm

# %%
X = qb_passing_df[passing_columns]
XAtt = qb_passing_df["Att"]
XCmp = qb_passing_df["Cmp"]
XYds = qb_passing_df["Yds"]
XTD = qb_passing_df["TD"]
XInt = qb_passing_df["Int"]
XQBR = qb_passing_df["QBR"]
XRate = qb_passing_df["Rate"]

Y = qb_passing_df["PassingFPs"]

# %%
X.dtypes

del X["QBrec"]
X = X.apply(pd.to_numeric)
XAtt = XAtt.apply(pd.to_numeric)
XCmp = XCmp.apply(pd.to_numeric)
XYds = XYds.apply(pd.to_numeric)
XTD = XTD.apply(pd.to_numeric)
XInt = XInt.apply(pd.to_numeric)
XQBR = XQBR.apply(pd.to_numeric)
XRate = XRate.apply(pd.to_numeric)

# %%
Y.dtypes
# Out:
# dtype('float64')

# %%
modelA = sm.OLS(Y, X).fit()

predictions = modelA.predict(X)

modelA.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             PassingFPs   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          4.508e+29
# Date:                Sun, 12 Jan 2020   Prob (F-statistic):                        0.00
# Time:                        13:24:53   Log-Likelihood:                          1773.6
# No. Observations:                  65   AIC:                                     -3507.
# Df Residuals:                      45   BIC:                                     -3464.
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
modelAtt = sm.OLS(Y, XAtt).fit()

predictions = modelAtt.predict(XAtt)

modelAtt.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             PassingFPs   R-squared (uncentered):                   0.971
# Model:                            OLS   Adj. R-squared (uncentered):              0.970
# Method:                 Least Squares   F-statistic:                              2128.
# Date:                Sun, 12 Jan 2020   Prob (F-statistic):                    7.86e-51
# Time:                        13:25:18   Log-Likelihood:                         -304.37
# No. Observations:                  65   AIC:                                      610.7
# Df Residuals:                      64   BIC:                                      612.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
modelCmp = sm.OLS(Y, XCmp).fit()

predictions = modelCmp.predict(XCmp)

modelCmp.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             PassingFPs   R-squared (uncentered):                   0.980
# Model:                            OLS   Adj. R-squared (uncentered):              0.979
# Method:                 Least Squares   F-statistic:                              3087.
# Date:                Sun, 12 Jan 2020   Prob (F-statistic):                    7.06e-56
# Time:                        13:26:01   Log-Likelihood:                         -292.58
# No. Observations:                  65   AIC:                                      587.2
# Df Residuals:                      64   BIC:                                      589.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
modelYds = sm.OLS(Y, XYds).fit()

predictions = modelYds.predict(XYds)

modelYds.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             PassingFPs   R-squared (uncentered):                   0.987
# Model:                            OLS   Adj. R-squared (uncentered):              0.987
# Method:                 Least Squares   F-statistic:                              4853.
# Date:                Sun, 12 Jan 2020   Prob (F-statistic):                    4.62e-62
# Time:                        13:26:38   Log-Likelihood:                         -278.12
# No. Observations:                  65   AIC:                                      558.2
# Df Residuals:                      64   BIC:                                      560.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
modelTD = sm.OLS(Y, XTD).fit()

predictions = modelTD.predict(XTD)

modelTD.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             PassingFPs   R-squared (uncentered):                   0.988
# Model:                            OLS   Adj. R-squared (uncentered):              0.988
# Method:                 Least Squares   F-statistic:                              5277.
# Date:                Sun, 12 Jan 2020   Prob (F-statistic):                    3.26e-63
# Time:                        13:27:30   Log-Likelihood:                         -275.42
# No. Observations:                  65   AIC:                                      552.8
# Df Residuals:                      64   BIC:                                      555.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
modelInt = sm.OLS(Y, XInt).fit()

predictions = modelInt.predict(XInt)

modelInt.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             PassingFPs   R-squared (uncentered):                   0.745
# Model:                            OLS   Adj. R-squared (uncentered):              0.741
# Method:                 Least Squares   F-statistic:                              187.1
# Date:                Sun, 12 Jan 2020   Prob (F-statistic):                    1.14e-20
# Time:                        13:29:16   Log-Likelihood:                         -374.78
# No. Observations:                  65   AIC:                                      751.6
# Df Residuals:                      64   BIC:                                      753.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
modelQBR = sm.OLS(Y, XQBR).fit()

predictions = modelQBR.predict(XQBR)

modelQBR.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             PassingFPs   R-squared (uncentered):                   0.738
# Model:                            OLS   Adj. R-squared (uncentered):              0.734
# Method:                 Least Squares   F-statistic:                              180.6
# Date:                Sun, 12 Jan 2020   Prob (F-statistic):                    2.69e-20
# Time:                        13:30:02   Log-Likelihood:                         -375.64
# No. Observations:                  65   AIC:                                      753.3
# Df Residuals:                      64   BIC:                                      755.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
modelRate = sm.OLS(Y, XRate).fit()

predictions = modelRate.predict(XRate)

modelRate.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             PassingFPs   R-squared (uncentered):                   0.683
# Model:                            OLS   Adj. R-squared (uncentered):              0.678
# Method:                 Least Squares   F-statistic:                              137.9
# Date:                Sun, 12 Jan 2020   Prob (F-statistic):                    1.30e-17
# Time:                        13:30:27   Log-Likelihood:                         -381.88
# No. Observations:                  65   AIC:                                      765.8
# Df Residuals:                      64   BIC:                                      767.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
